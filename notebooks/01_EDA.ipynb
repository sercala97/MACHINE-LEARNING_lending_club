# %% [markdown]
# ## Análisis Exploratorio de datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
from scipy import stats

#To plot figs on jupyter
# %matplotlib inline
# figure size in inches
rcParams['figure.figsize'] = 14,6

# %%
lendingclub = pd.read_csv('./data/01_raw_general.csv', sep = ',')
lendingclub.head()
# Out:
# C:\Users\nacho\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (19,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  112435993        NaN     2300.0       2300.0           2300.0   36 months
# 1  112290210        NaN    16000.0      16000.0          16000.0   60 months
# 2  112436985        NaN     6025.0       6025.0           6025.0   36 months
# 3  112439006        NaN    20400.0      20400.0          20400.0   36 months
# 4  112438929        NaN    13000.0      13000.0          13000.0   36 months
#
#   int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0   12.62%        77.08     C        C1  ...                            NaN
# 1   12.62%       360.95     C        C1  ...                            NaN
# 2   15.05%       209.01     C        C4  ...                            NaN
# 3    9.44%       652.91     B        B1  ...                            NaN
# 4   11.99%       431.73     B        B5  ...                            NaN
#
#   hardship_last_payment_amount disbursement_method  debt_settlement_flag  \
# 0                          NaN                Cash                     N
# 1                          NaN                Cash                     N
# 2                          NaN                Cash                     N
# 3                          NaN                Cash                     N
# 4                          NaN                Cash                     N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#   settlement_amount settlement_percentage settlement_term
# 0               NaN                   NaN             NaN
# 1               NaN                   NaN             NaN
# 2               NaN                   NaN             NaN
# 3               NaN                   NaN             NaN
# 4               NaN                   NaN             NaN
#
# [5 rows x 151 columns]

# %% [markdown]
# ### Valores perdidos

# %%
nacolumnas = pd.DataFrame(lendingclub.isna().sum(), columns = ['Valores NaN']).sort_values(['Valores NaN'], ascending = False)
pd.set_option('display.max_rows', nacolumnas.shape[0]+1)
nacolumnas
# Out:
#                                             Valores NaN
# member_id                                        884876
# orig_projected_additional_accrued_interest       882607
# hardship_end_date                                882215
# hardship_amount                                  882215
# hardship_type                                    882215
# hardship_reason                                  882215
# hardship_status                                  882215
# hardship_last_payment_amount                     882215
# hardship_payoff_balance_amount                   882215
# hardship_loan_status                             882215
# hardship_dpd                                     882215
# hardship_length                                  882215
# payment_plan_start_date                          882215
# deferral_term                                    882215
# hardship_start_date                              882215
# sec_app_mths_since_last_major_derog              877691
# settlement_term                                  876356
# debt_settlement_flag_date                        876356
# settlement_status                                876356
# settlement_date                                  876356
# settlement_amount                                876356
# settlement_percentage                            876356
# desc                                             869552
# sec_app_revol_util                               864358
# sec_app_inq_last_6mths                           864076
# revol_bal_joint                                  864076
# sec_app_fico_range_low                           864076
# sec_app_fico_range_high                          864076
# sec_app_earliest_cr_line                         864076
# sec_app_open_act_il                              864076
# sec_app_mort_acc                                 864076
# sec_app_chargeoff_within_12_mths                 864076
# sec_app_open_acc                                 864076
# sec_app_collections_12_mths_ex_med               864076
# sec_app_num_rev_accts                            864076
# dti_joint                                        863560
# verification_status_joint                        863558
# annual_inc_joint                                 863558
# mths_since_last_record                           729776
# il_util                                          668295
# mths_since_recent_bc_dlq                         659442
# mths_since_rcnt_il                               642103
# all_util                                         635379
# open_rv_24m                                      635352
# open_rv_12m                                      635352
# inq_last_12m                                     635352
# total_bal_il                                     635352
# open_il_24m                                      635352
# open_il_12m                                      635352
# open_act_il                                      635352
# open_acc_6m                                      635352
# total_cu_tl                                      635352
# max_bal_bc                                       635352
# inq_fi                                           635352
# mths_since_last_major_derog                      633263
# mths_since_recent_revol_delinq                   569042
# next_pymnt_d                                     442567
# mths_since_last_delinq                           431427
# mths_since_recent_inq                             92130
# emp_title                                         52693
# emp_length                                        51193
# num_tl_120dpd_2m                                  37803
# mo_sin_old_il_acct                                25614
# bc_util                                            9824
# percent_bc_gt_75                                   9680
# bc_open_to_buy                                     9287
# mths_since_recent_bc                               8763
# last_pymnt_d                                        758
# revol_util                                          489
# dti                                                 261
# title                                               132
# last_credit_pull_d                                   38
# avg_cur_bal                                          13
# num_rev_accts                                         1
# annual_inc                                            0
# fico_range_low                                        0
# fico_range_high                                       0
# inq_last_6mths                                        0
# funded_amnt                                           0
# open_acc                                              0
# pub_rec                                               0
# revol_bal                                             0
# grade                                                 0
# term                                                  0
# total_il_high_credit_limit                            0
# loan_amnt                                             0
# total_bc_limit                                        0
# total_bal_ex_mort                                     0
# tot_hi_cred_lim                                       0
# tax_liens                                             0
# funded_amnt_inv                                       0
# earliest_cr_line                                      0
# verification_status                                   0
# pub_rec_bankruptcies                                  0
# issue_d                                               0
# loan_status                                           0
# pymnt_plan                                            0
# url                                                   0
# purpose                                               0
# home_ownership                                        0
# debt_settlement_flag                                  0
# sub_grade                                             0
# hardship_flag                                         0
# int_rate                                              0
# zip_code                                              0
# installment                                           0
# disbursement_method                                   0
# delinq_2yrs                                           0
# addr_state                                            0
# num_sats                                              0
# pct_tl_nvr_dlq                                        0
# initial_list_status                                   0
# out_prncp_inv                                         0
# total_rev_hi_lim                                      0
# total_pymnt                                           0
# total_pymnt_inv                                       0
# total_rec_prncp                                       0
# total_rec_int                                         0
# total_rec_late_fee                                    0
# recoveries                                            0
# collection_recovery_fee                               0
# last_pymnt_amnt                                       0
# tot_cur_bal                                           0
# tot_coll_amt                                          0
# acc_now_delinq                                        0
# last_fico_range_high                                  0
# last_fico_range_low                                   0
# collections_12_mths_ex_med                            0
# application_type                                      0
# out_prncp                                             0
# acc_open_past_24mths                                  0
# num_tl_op_past_12m                                    0
# chargeoff_within_12_mths                              0
# num_tl_90g_dpd_24m                                    0
# num_tl_30dpd                                          0
# policy_code                                           0
# num_rev_tl_bal_gt_0                                   0
# num_op_rev_tl                                         0
# num_il_tl                                             0
# num_bc_tl                                             0
# num_bc_sats                                           0
# num_actv_rev_tl                                       0
# num_actv_bc_tl                                        0
# num_accts_ever_120_pd                                 0
# total_acc                                             0
# mort_acc                                              0
# mo_sin_rcnt_tl                                        0
# mo_sin_rcnt_rev_tl_op                                 0
# mo_sin_old_rev_tl_op                                  0
# delinq_amnt                                           0
# id                                                    0

# %% [markdown]
# ### Variable Target

# %% [markdown]
# La variable objetivo en este trabajo es `Loan Status`. Vamos a estudiar todos los status.

# %%
total = len(lendingclub)
plt.figure(figsize = (14,13))
g = sns.countplot(x="loan_status", data=lendingclub, 
                  color='blue')
g.set_xticklabels(g.get_xticklabels(),rotation=45)
g.set_xlabel("Categorias de Loan Status", fontsize=12)
g.set_ylabel("Count", fontsize=15)
g.set_title("Distribución de tipos de Loan Status", fontsize=20)
sizes=[]
for p in g.patches:
    height = p.get_height()
    sizes.append(height)
    g.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=12) 
g.set_ylim(0, max(sizes) * 1.10)
plt.show()

# %% [markdown]
# ### Propósito del crédito

# %%
plt.figure(figsize=(14,6))

g = sns.countplot(x='purpose', data=lendingclub, 
                  color='blue')
g.set_title("Propósito de Crédito de los Clientes", fontsize=22)
g.set_xlabel("Propósito", fontsize=18)
g.set_ylabel('Count', fontsize=18)

sizes=[]

for p in g.patches:
    height = p.get_height()
    sizes.append(height)
    g.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=14) 
    
g.set_ylim(0, max(sizes) * 1.10)
g.set_xticklabels(g.get_xticklabels(),
                  rotation=45)

plt.show()

# %% [markdown]
# ### Distribuciones de la cantidad del préstamo y tipo de interés

# %%
int_numeric = lendingclub["int_rate"].str.strip("%")
int_numeric = pd.to_numeric(int_numeric)
lendingclub["int_rate"] = int_numeric/100

lendingclub['int_round'] = lendingclub['int_rate'].round(0).astype(int)

#I will start looking the loan_amnt column
plt.figure(figsize=(14,10))

# Loan Amt plot
plt.subplot(211)
g = sns.distplot(lendingclub["loan_amnt"])
g.set_xlabel("Loan Amount Value", fontsize=16)
g.set_ylabel("Frequency", fontsize=16)
g.set_title("Loan Amount Distribuition", fontsize=20)

## Interest plot
plt.subplot(212)
g1 = sns.countplot(x="int_round", data=lendingclub, 
                  color='blue')
g1.set_xlabel("Loan Interest Rate", fontsize=16)
g1.set_ylabel("Count", fontsize=16)
g1.set_title("Interest Rate Distribuition", fontsize=20)
sizes=[] # Get highest values in y
for p in g1.patches:
    height = p.get_height()
    sizes.append(height)
    g1.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=12) 
g1.set_ylim(0, max(sizes) * 1.10) # set y limit based on highest heights

plt.subplots_adjust(hspace = 0.4,top = 0.9)

plt.show()

# %% [markdown]
# ### Estado de verificación

# %%
plt.figure(figsize = (13,6))

g = sns.countplot(x = "verification_status", data = lendingclub, 
                  color='blue')
g.set_xlabel("Categorias de Loan Status", fontsize = 15)
g.set_ylabel("Count", fontsize = 15)
g.set_title("Distribucion tipo de Loan Status", fontsize = 20)
sizes=[]
for p in g.patches:
    height = p.get_height()
    sizes.append(height)
    g.text(p.get_x() + p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize = 14) 
g.set_ylim(0, max(sizes) * 1.10)

plt.show()

# %% [markdown]
# ### INSTALLMENT Column

# %%
plt.figure(figsize=(12,5))

sns.distplot(lendingclub['installment'])
plt.title("Installment Distribution", fontsize = 20)
plt.xlabel("Installment Range", fontsize = 17)
plt.ylabel("Density", fontsize = 17)

plt.show()

# %% [markdown]
# ### Installment by Loan Status

# %%
plt.figure(figsize = (14,12))

plt.subplot(211)
g = sns.violinplot(x='loan_status', y="installment",
                   data=lendingclub, color='blue')
g.set_xticklabels(g.get_xticklabels(),rotation=45)
g.set_xlabel("Loan Status", fontsize=17)
g.set_ylabel("Pago", fontsize=17)
g.set_title("Cuotas por estado del préstamo", fontsize=20)

plt.subplot(212)
g1 = sns.violinplot(x='loan_status', y="total_acc",
                   data=lendingclub, color='blue')
g1.set_xticklabels(g.get_xticklabels(),rotation=45)
g1.set_xlabel("Loan Status", fontsize=17)
g1.set_ylabel("Líneas de cuenta totales", fontsize=17)
g1.set_title("Distribución total de líneas de cuenta por estado de préstamo", fontsize=20)

plt.subplots_adjust(hspace = 0.5,top = 0.9)

plt.show()

# %% [markdown]
# ### Terms

# %%
order_sub = lendingclub.groupby("sub_grade")['int_rate'].count().index

plt.figure(figsize=(14,18))

plt.suptitle('Term Distributions \n# Count, Interest Rate and Loan Amount #', fontsize=22)

plt.subplot(311)
g = sns.countplot(x="term", data=lendingclub,color='blue')
g.set_xlabel("Term Values", fontsize=17)
g.set_ylabel("Count", fontsize=17)
g.set_title("Lending Club Loan \nTerm Count Distribution", fontsize=20)
sizes=[]
for p in g.patches:
    height = p.get_height()
    sizes.append(height)
    g.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=14) 
g.set_ylim(0, max(sizes) * 1.10)

plt.subplot(312)
g1 = sns.violinplot(x='term', y="int_rate",data=lendingclub )
g1.set_xlabel("Term Values", fontsize=17)
g1.set_ylabel("Interest Rate", fontsize=17)
g1.set_title("Lending Club Loan \nInterest Rate Distribution by Term Values", fontsize=20)

plt.subplot(313)
g2 = sns.violinplot(x="term", y="loan_amnt", data=lendingclub)
g2.set_xlabel("Term Values", fontsize=17)
g2.set_ylabel("Loan Amount", fontsize=17)
g2.set_title("Lending Club Loan \nLoan Amount Distribution by Term Values", fontsize=20)

plt.subplots_adjust(hspace = 0.4, top = 0.9)

plt.show()

# %% [markdown]
# ### Grades

# %%
order_sub = lendingclub.groupby("sub_grade")['int_rate'].count().index

plt.figure(figsize=(14,16))

plt.suptitle('Grade and Sub-Grade Distributions \n# Interest Rate and Loan Amount #', fontsize=22)

plt.subplot(311)
g = sns.boxplot(x="grade", y="loan_amnt", data=lendingclub,
                palette="hls", hue="application_type", 
                order=["A",'B','C','D','E','F', 'G'])
g.set_xlabel("Grade Values", fontsize=17)
g.set_ylabel("Loan Amount", fontsize=17)
g.set_title("Lending Club Loan - Loan Amount Distribution by Grade", fontsize=20)
g.legend(loc='upper right')

plt.subplot(312)
g1 = sns.boxplot(x='grade', y="int_rate",data=lendingclub, 
               hue="application_type", palette = "hls",  
               order=["A",'B','C','D','E','F', 'G'])
g1.set_xlabel("Grade Values", fontsize=17)
g1.set_ylabel("Interest Rate", fontsize=17)
g1.set_title("Lending Club Loan - Interest Rate Distribution by Grade", fontsize=20)

plt.subplot(313)
g2 = sns.boxenplot(x="sub_grade", y="int_rate", data=lendingclub, 
                   palette="hls", order=order_sub)
g2.set_xlabel("Sub Grade Values", fontsize=15)
g2.set_ylabel("Interest Rate", fontsize=15)
g2.set_title("Lending Club Loan - Interest Rate Distribution by Sub-Grade", fontsize=20)

plt.subplots_adjust(hspace = 0.4,top = 0.9)

plt.show()

# %% [markdown]
# ### Matriz de correlación

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Compute the correlation matrix
corr = lendingclub.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# Como se puede apreciar, esta matriz de correlaciones apenas aporta información acerca de las posibles variables relevantes para realizar los modelos debido al gran número de variables deldataset. A continuación se va a proceder a la selección de aquellas variables que nos resultan importantes.

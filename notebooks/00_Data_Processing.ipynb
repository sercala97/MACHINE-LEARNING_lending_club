# %% [markdown]
# ## Load dataset

# %%
import pandas as pd

# %%
loan_training_set1 = pd.read_csv('./data/01_raw/Loan_training_set_1_4.csv', sep = ',' , skiprows=1)
loan_training_set1.drop(loan_training_set1.index[105451], inplace=True)
loan_training_set1.drop(loan_training_set1.index[105451], inplace=True)
loan_training_set1
# Out:
# C:\Users\nacho\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (0,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0       112435993        NaN     2300.0       2300.0           2300.0
# 1       112290210        NaN    16000.0      16000.0          16000.0
# 2       112436985        NaN     6025.0       6025.0           6025.0
# 3       112439006        NaN    20400.0      20400.0          20400.0
# 4       112438929        NaN    13000.0      13000.0          13000.0
# ...           ...        ...        ...          ...              ...
# 105446  102556443        NaN    24000.0      24000.0          24000.0
# 105447  102653304        NaN    10000.0      10000.0          10000.0
# 105448  102628603        NaN    10050.0      10050.0          10050.0
# 105449  102196576        NaN     6000.0       6000.0           6000.0
# 105450   99799684        NaN    30000.0      30000.0          30000.0
#
#               term int_rate  installment grade sub_grade  ...  \
# 0        36 months   12.62%        77.08     C        C1  ...
# 1        60 months   12.62%       360.95     C        C1  ...
# 2        36 months   15.05%       209.01     C        C4  ...
# 3        36 months    9.44%       652.91     B        B1  ...
# 4        36 months   11.99%       431.73     B        B5  ...
# ...            ...      ...          ...   ...       ...  ...
# 105446   60 months   23.99%       690.30     E        E2  ...
# 105447   36 months    7.99%       313.32     A        A5  ...
# 105448   36 months   16.99%       358.26     D        D1  ...
# 105449   36 months   11.44%       197.69     B        B4  ...
# 105450   60 months   25.49%       889.18     E        E4  ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
# ...                               ...                          ...
# 105446                            NaN                          NaN
# 105447                            NaN                          NaN
# 105448                            NaN                          NaN
# 105449                            NaN                          NaN
# 105450                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                     Cash                     N                       NaN
# 1                     Cash                     N                       NaN
# 2                     Cash                     N                       NaN
# 3                     Cash                     N                       NaN
# 4                     Cash                     N                       NaN
# ...                    ...                   ...                       ...
# 105446                Cash                     N                       NaN
# 105447                Cash                     N                       NaN
# 105448                Cash                     N                       NaN
# 105449                Cash                     N                       NaN
# 105450                Cash                     N                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 0                    NaN             NaN               NaN
# 1                    NaN             NaN               NaN
# 2                    NaN             NaN               NaN
# 3                    NaN             NaN               NaN
# 4                    NaN             NaN               NaN
# ...                  ...             ...               ...
# 105446               NaN             NaN               NaN
# 105447               NaN             NaN               NaN
# 105448               NaN             NaN               NaN
# 105449               NaN             NaN               NaN
# 105450               NaN             NaN               NaN
#
#        settlement_percentage  settlement_term
# 0                        NaN              NaN
# 1                        NaN              NaN
# 2                        NaN              NaN
# 3                        NaN              NaN
# 4                        NaN              NaN
# ...                      ...              ...
# 105446                   NaN              NaN
# 105447                   NaN              NaN
# 105448                   NaN              NaN
# 105449                   NaN              NaN
# 105450                   NaN              NaN
#
# [105451 rows x 151 columns]

# %%
loan_training_set2 = pd.read_csv('./data/01_raw/Loan_training_set_2_4.csv', sep = ',' , skiprows=1)
loan_training_set2.drop(loan_training_set2.index[122701], inplace=True)
loan_training_set2.drop(loan_training_set2.index[122701], inplace=True)
loan_training_set2
# Out:
# C:\Users\nacho\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (0,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0       118659541        NaN    33000.0      33000.0          33000.0
# 1       119321612        NaN    40000.0      40000.0          40000.0
# 2       120122535        NaN    12000.0      12000.0          12000.0
# 3       119246018        NaN     7000.0       7000.0           7000.0
# 4       119374887        NaN    32000.0      32000.0          32000.0
# ...           ...        ...        ...          ...              ...
# 122696  110380307        NaN     6000.0       6000.0           6000.0
# 122697  110479222        NaN    20000.0      20000.0          20000.0
# 122698  109866673        NaN    35000.0      35000.0          35000.0
# 122699  110394553        NaN    30775.0      30775.0          30525.0
# 122700  109517381        NaN    18900.0      18900.0          18900.0
#
#               term int_rate  installment grade sub_grade  ...  \
# 0        36 months    7.21%      1022.12     A        A3  ...
# 1        60 months   15.05%       952.65     C        C4  ...
# 2        36 months    7.97%       375.88     A        A5  ...
# 3        36 months    7.97%       219.26     A        A5  ...
# 4        36 months   11.99%      1062.71     B        B5  ...
# ...            ...      ...          ...   ...       ...  ...
# 122696   36 months   23.88%       235.02     E        E2  ...
# 122697   60 months   26.30%       602.37     E        E5  ...
# 122698   60 months   30.89%      1151.58     G        G3  ...
# 122699   60 months   30.65%      1008.00     F        F4  ...
# 122700   60 months   30.94%       622.44     G        G4  ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
# ...                               ...                          ...
# 122696                            NaN                          NaN
# 122697                            NaN                          NaN
# 122698                            NaN                          NaN
# 122699                            NaN                          NaN
# 122700                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                     Cash                     N                       NaN
# 1                     Cash                     N                       NaN
# 2                     Cash                     N                       NaN
# 3                     Cash                     N                       NaN
# 4                     Cash                     N                       NaN
# ...                    ...                   ...                       ...
# 122696                Cash                     N                       NaN
# 122697                Cash                     N                       NaN
# 122698                Cash                     N                       NaN
# 122699                Cash                     N                       NaN
# 122700                Cash                     N                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 0                    NaN             NaN               NaN
# 1                    NaN             NaN               NaN
# 2                    NaN             NaN               NaN
# 3                    NaN             NaN               NaN
# 4                    NaN             NaN               NaN
# ...                  ...             ...               ...
# 122696               NaN             NaN               NaN
# 122697               NaN             NaN               NaN
# 122698               NaN             NaN               NaN
# 122699               NaN             NaN               NaN
# 122700               NaN             NaN               NaN
#
#        settlement_percentage  settlement_term
# 0                        NaN              NaN
# 1                        NaN              NaN
# 2                        NaN              NaN
# 3                        NaN              NaN
# 4                        NaN              NaN
# ...                      ...              ...
# 122696                   NaN              NaN
# 122697                   NaN              NaN
# 122698                   NaN              NaN
# 122699                   NaN              NaN
# 122700                   NaN              NaN
#
# [122701 rows x 151 columns]

# %%
loan_training_set3 = pd.read_csv('./data/01_raw/Loan_training_set_3_4.csv', sep = ',' , skiprows=1)
loan_training_set3.drop(loan_training_set3.index[235629], inplace=True)
loan_training_set3.drop(loan_training_set3.index[235629], inplace=True)
loan_training_set3
# Out:
# C:\Users\nacho\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (0,19,129,130,131,134,135,136,139) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0       38098114        NaN    15000.0      15000.0          15000.0
# 1       36805548        NaN    10400.0      10400.0          10400.0
# 2       37842129        NaN    21425.0      21425.0          21425.0
# 3       37612354        NaN    12800.0      12800.0          12800.0
# 4       37662224        NaN     7650.0       7650.0           7650.0
# ...          ...        ...        ...          ...              ...
# 235624   8598660        NaN    18400.0      18400.0          18400.0
# 235625   9684700        NaN    22000.0      22000.0          22000.0
# 235626   9604874        NaN     2000.0       2000.0           2000.0
# 235627   9584776        NaN    20700.0      20700.0          20700.0
# 235628   9199665        NaN    10000.0      10000.0           9975.0
#
#               term int_rate  installment grade sub_grade  ...  \
# 0        60 months   12.39%       336.64     C        C1  ...
# 1        36 months    6.99%       321.08     A        A3  ...
# 2        60 months   15.59%       516.36     D        D1  ...
# 3        60 months   17.14%       319.08     D        D4  ...
# 4        36 months   13.66%       260.20     C        C3  ...
# ...            ...      ...          ...   ...       ...  ...
# 235624   60 months   14.47%       432.64     C        C2  ...
# 235625   60 months   19.97%       582.50     D        D5  ...
# 235626   36 months    7.90%        62.59     A        A4  ...
# 235627   60 months   16.99%       514.34     D        D1  ...
# 235628   36 months   19.20%       367.58     D        D3  ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
# ...                               ...                          ...
# 235624                            NaN                          NaN
# 235625                            NaN                          NaN
# 235626                            NaN                          NaN
# 235627                            NaN                          NaN
# 235628                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                     Cash                     N                       NaN
# 1                     Cash                     N                       NaN
# 2                     Cash                     N                       NaN
# 3                     Cash                     N                       NaN
# 4                     Cash                     N                       NaN
# ...                    ...                   ...                       ...
# 235624                Cash                     N                       NaN
# 235625                Cash                     N                       NaN
# 235626                Cash                     N                       NaN
# 235627                Cash                     N                       NaN
# 235628                Cash                     N                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 0                    NaN             NaN               NaN
# 1                    NaN             NaN               NaN
# 2                    NaN             NaN               NaN
# 3                    NaN             NaN               NaN
# 4                    NaN             NaN               NaN
# ...                  ...             ...               ...
# 235624               NaN             NaN               NaN
# 235625               NaN             NaN               NaN
# 235626               NaN             NaN               NaN
# 235627               NaN             NaN               NaN
# 235628               NaN             NaN               NaN
#
#        settlement_percentage settlement_term
# 0                        NaN             NaN
# 1                        NaN             NaN
# 2                        NaN             NaN
# 3                        NaN             NaN
# 4                        NaN             NaN
# ...                      ...             ...
# 235624                   NaN             NaN
# 235625                   NaN             NaN
# 235626                   NaN             NaN
# 235627                   NaN             NaN
# 235628                   NaN             NaN
#
# [235629 rows x 151 columns]

# %%
loan_training_set4 = pd.read_csv('./data/01_raw/Loan_training_set_4_4.csv', sep = ',' , skiprows=1)
loan_training_set4.drop(loan_training_set4.index[421095], inplace=True)
loan_training_set4.drop(loan_training_set4.index[421095], inplace=True)
loan_training_set4
# Out:
# C:\Users\nacho\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (0,19,59) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0       68506789        NaN    12000.0      12000.0          12000.0
# 1       68426545        NaN    16000.0      16000.0          16000.0
# 2       68394562        NaN    30000.0      30000.0          30000.0
# 3       66583801        NaN    33600.0      33600.0          33600.0
# 4       68466916        NaN    25000.0      25000.0          25000.0
# ...          ...        ...        ...          ...              ...
# 421090  36371250        NaN    10000.0      10000.0          10000.0
# 421091  36441262        NaN    24000.0      24000.0          24000.0
# 421092  36271333        NaN    13000.0      13000.0          13000.0
# 421093  36490806        NaN    12000.0      12000.0          12000.0
# 421094  36271262        NaN    20000.0      20000.0          20000.0
#
#               term int_rate  installment grade sub_grade  ...  \
# 0        60 months    9.80%       253.79     B        B3  ...
# 1        60 months   12.88%       363.07     C        C2  ...
# 2        36 months   15.77%      1051.31     D        D1  ...
# 3        36 months   10.78%      1096.53     B        B4  ...
# 4        36 months    7.49%       777.55     A        A4  ...
# ...            ...      ...          ...   ...       ...  ...
# 421090   36 months   11.99%       332.10     B        B5  ...
# 421091   36 months   11.99%       797.03     B        B5  ...
# 421092   60 months   15.99%       316.07     D        D2  ...
# 421093   60 months   19.99%       317.86     E        E3  ...
# 421094   36 months   11.99%       664.20     B        B5  ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
# ...                               ...                          ...
# 421090                            NaN                          NaN
# 421091                            NaN                          NaN
# 421092                            NaN                          NaN
# 421093                            NaN                          NaN
# 421094                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                     Cash                     N                       NaN
# 1                     Cash                     N                       NaN
# 2                     Cash                     N                       NaN
# 3                     Cash                     N                       NaN
# 4                     Cash                     N                       NaN
# ...                    ...                   ...                       ...
# 421090                Cash                     N                       NaN
# 421091                Cash                     N                       NaN
# 421092                Cash                     N                       NaN
# 421093                Cash                     N                       NaN
# 421094                Cash                     N                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 0                    NaN             NaN               NaN
# 1                    NaN             NaN               NaN
# 2                    NaN             NaN               NaN
# 3                    NaN             NaN               NaN
# 4                    NaN             NaN               NaN
# ...                  ...             ...               ...
# 421090               NaN             NaN               NaN
# 421091               NaN             NaN               NaN
# 421092               NaN             NaN               NaN
# 421093               NaN             NaN               NaN
# 421094               NaN             NaN               NaN
#
#        settlement_percentage settlement_term
# 0                        NaN             NaN
# 1                        NaN             NaN
# 2                        NaN             NaN
# 3                        NaN             NaN
# 4                        NaN             NaN
# ...                      ...             ...
# 421090                   NaN             NaN
# 421091                   NaN             NaN
# 421092                   NaN             NaN
# 421093                   NaN             NaN
# 421094                   NaN             NaN
#
# [421095 rows x 151 columns]

# %%
frames = [loan_training_set1, loan_training_set2, loan_training_set3,loan_training_set4]
lendingclub = pd.concat(frames)

# %%
lendingclub.to_csv('./data/01_raw_general.csv', index = False)
